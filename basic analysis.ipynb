# %%
import pandas as pd

# %%
df=pd.read_csv('5m_Sales_Records.csv')

# %%
df.head()
# Out:
#                          Region  Country        Item Type Sales Channel  \
# 0         Australia and Oceania    Palau  Office Supplies        Online
# 1                        Europe   Poland        Beverages        Online
# 2                 North America   Canada           Cereal        Online
# 3                        Europe  Belarus           Snacks        Online
# 4  Middle East and North Africa     Oman           Cereal       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H   3/6/2016  517073523  3/26/2016        2401      651.21
# 1              L  4/18/2010  380507028  5/26/2010        9340       47.45
# 2              M   1/8/2015  504055583  1/31/2015         103      205.70
# 3              C  1/19/2014  954955518  2/27/2014        1414      152.58
# 4              H  4/26/2019  970755660   6/2/2019        7027      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df.groupby('Order ID')['Total Cost'].count()
# Out:
# Order ID
# 100000321    3
# 100000751    2
# 100001180    2
# 100001609    3
# 100002038    2
#             ..
# 999998176    3
# 999998605    2
# 999999034    2
# 999999463    2
# 999999892    3
# Name: Total Cost, Length: 2097152, dtype: int64

# %%
df.loc[df['Order ID']==100000321]
# Out:
#                      Region       Country Item Type Sales Channel  \
# 1013029  Sub-Saharan Africa  Sierra Leone    Fruits       Offline
# 2666309  Sub-Saharan Africa  Sierra Leone    Fruits       Offline
# 4313637  Sub-Saharan Africa  Sierra Leone    Fruits       Offline
#
#         Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 1013029              M  3/20/2010  100000321  4/24/2010        1172
# 2666309              M  3/20/2010  100000321  4/24/2010        1172
# 4313637              M  3/20/2010  100000321  4/24/2010        1172
#
#          Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 1013029        9.33       6.92       10934.76     8110.24       2824.52
# 2666309        9.33       6.92       10934.76     8110.24       2824.52
# 4313637        9.33       6.92       10934.76     8110.24       2824.52

# %%
df.loc[df['Order ID']==999998176]
# Out:
#                      Region   Country        Item Type Sales Channel  \
# 423344   Sub-Saharan Africa  Botswana  Office Supplies       Offline
# 2033200  Sub-Saharan Africa  Botswana  Office Supplies       Offline
# 3920080  Sub-Saharan Africa  Botswana  Office Supplies       Offline
#
#         Order Priority Order Date   Order ID Ship Date  Units Sold  \
# 423344               C  3/29/2016  999998176  4/4/2016         537
# 2033200              C  3/29/2016  999998176  4/4/2016         537
# 3920080              C  3/29/2016  999998176  4/4/2016         537
#
#          Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 423344       651.21     524.96      349699.77   281903.52      67796.25
# 2033200      651.21     524.96      349699.77   281903.52      67796.25
# 3920080      651.21     524.96      349699.77   281903.52      67796.25

# %%
df.loc[df['Order ID']==100000751]
# Out:
#          Region Country  Item Type Sales Channel Order Priority Order Date  \
# 1781782  Europe  Sweden  Household       Offline              H  4/15/2013
# 3224790  Europe  Sweden  Household       Offline              H  4/15/2013
#
#           Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 1781782  100000751  5/16/2013        1299      668.27     502.54
# 3224790  100000751  5/16/2013        1299      668.27     502.54
#
#          Total Revenue  Total Cost  Total Profit
# 1781782      868082.73   652799.46     215283.27
# 3224790      868082.73   652799.46     215283.27

# %%
df=df.loc[:3000000,:]

# %%
df.shape
# Out:
# (3000001, 14)

# %%
df.groupby('Order ID')['Total Cost'].count()
# Out:
# Order ID
# 100000321    2
# 100000751    1
# 100001180    1
# 100001609    1
# 100002038    1
#             ..
# 999998176    2
# 999998605    1
# 999999034    1
# 999999463    1
# 999999892    2
# Name: Total Cost, Length: 2043424, dtype: int64

# %%
df.loc[df['Order ID']==100000321]
# Out:
#                      Region       Country Item Type Sales Channel  \
# 1013029  Sub-Saharan Africa  Sierra Leone    Fruits       Offline
# 2666309  Sub-Saharan Africa  Sierra Leone    Fruits       Offline
#
#         Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 1013029              M  3/20/2010  100000321  4/24/2010        1172
# 2666309              M  3/20/2010  100000321  4/24/2010        1172
#
#          Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 1013029        9.33       6.92       10934.76     8110.24       2824.52
# 2666309        9.33       6.92       10934.76     8110.24       2824.52
